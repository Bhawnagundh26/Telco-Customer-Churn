# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from sklearn import metrics
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.metrics import recall_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df=pd.read_csv('tel_churn.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True        False       False         True           True  ...
# 1          False         True        True        False           True  ...
# 2          False         True        True        False           True  ...
# 3          False         True        True        False           True  ...
# 4           True        False        True        False           True  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
if 'Unnamed: 0' in df.columns:
    df = df.drop('Unnamed: 0', axis=1)
else:
    print("'Unnamed: 0' not found in DataFrame columns")
df = df.drop('Unnamed: 0', axis=1, errors='ignore')
# Out:
# 'Unnamed: 0' not found in DataFrame columns

# %%
df.head(5)
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0           True
# 1              0           56.95       1889.50      0          False
# 2              0           53.85        108.15      1          False
# 3              0           42.30       1840.75      0          False
# 4              0           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
x=df.drop('Churn',axis=1)
print(x)
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85           True        False
# 1                 0           56.95       1889.50          False         True
# 2                 0           53.85        108.15          False         True
# 3                 0           42.30       1840.75          False         True
# 4                 0           70.70        151.65           True        False
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50          False         True
# 7028              0          103.20       7362.90           True        False
# 7029              0           29.60        346.45           True        False
# 7030              1           74.40        306.60          False         True
# 7031              0          105.65       6844.50          False         True
#
# ...

# %%
y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier


model_dt = DecisionTreeClassifier(criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred = model_dt.predict(x_test)

# %% [raw]
# y_pred

# %%
model_dt_score = model_dt.score(x_test, y_pred)
print("Model accuracy on test set:", model_dt_score)
# Out:
# Model accuracy on test set: 1.0

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85      1026
#            1       0.60      0.53      0.56       381
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.70      0.71      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
from sklearn.metrics import confusion_matrix


print(confusion_matrix(y_test, y_pred))
# Out:
# [[892 134]
#  [180 201]]

# %%
from imblearn.combine import SMOTEENN


sm = SMOTEENN()
X_resampled, y_resampled = sm.fit_resample(x, y)

# %%
from imblearn.combine import SMOTEENN
from sklearn.model_selection import train_test_split

xr_train, xr_test, yr_train, yr_test = train_test_split(X_resampled, y_resampled, test_size=0.2)

# %%
model_dt = DecisionTreeClassifier(criterion ='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
from sklearn.tree import DecisionTreeClassifier


model_dt_smote = DecisionTreeClassifier()


model_dt_smote.fit(xr_train, yr_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier()

model_dt.fit(x_train, y_train)

y_pred = model_dt.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81      1026
#            1       0.50      0.49      0.49       381
#
#     accuracy                           0.73      1407
#    macro avg       0.65      0.65      0.65      1407
# weighted avg       0.73      0.73      0.73      1407

# %% [raw]
# print(confusion_matrix(y_test, y_pred_smote))

# %% [markdown]
# #random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model_smote_rf = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

model_smote_rf.fit(xr_train, yr_train)

y_pred_rf = model_rf.predict(xr_test)

# %%
print(classification_report(yr_test,y_pred_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.99      0.80       503
#            1       0.99      0.63      0.77       670
#
#     accuracy                           0.78      1173
#    macro avg       0.83      0.81      0.78      1173
# weighted avg       0.85      0.78      0.78      1173

# %%
print(confusion_matrix(yr_test, y_pred_rf))
# Out:
# [[497   6]
#  [247 423]]

# %%
import pickle
filename = 'model.sav'

with open(filename, 'wb') as file:
    pickle.dump(model_smote_rf, file)

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
load_model.score(xr_test,yr_test)
# Out:
# 0.9215686274509803

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9)


xr_train1 = pca.fit_transform(x_train, y_train)

# %%
xr_test1 = pca.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

model_pca = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=10, max_depth=6, min_samples_leaf=8)

# %%
model_pca.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=10)

# %%
y_pred_pca = model_pca.predict(x_test)

# %%
print(classification_report(y_test,y_pred_pca, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86      1026
#            1       0.66      0.44      0.53       381
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.68      0.70      1407
# weighted avg       0.77      0.79      0.77      1407
